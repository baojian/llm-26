# %% [markdown]
# jupyter nbconvert --to html --template classic lecture-01-exercise-NLP-LLMs-introduction.ipynb

# %%
# !conda env export --from-history > environment-test.yml
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/conda/base/context.py:201: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(

# %%
# !jupyter nbconvert lecture-01-exercise-NLP-LLMs-introduction.ipynb --to html --template classic --embed-images
# Out:
# [NbConvertApp] Converting notebook lecture-01-exercise-NLP-LLMs-introduction.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 5 image(s).
# [NbConvertApp] Writing 13605549 bytes to lecture-01-exercise-NLP-LLMs-introduction.html

# %%
# !jupyter nbconvert --to html --template classic --embed-images \
  --TemplateExporter.exclude_input=False \
  lecture-01-exercise-NLP-LLMs-introduction.ipynb
# Out:
# [NbConvertApp] Converting notebook lecture-01-exercise-NLP-LLMs-introduction.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 5 image(s).
# [NbConvertApp] Writing 13599453 bytes to lecture-01-exercise-NLP-LLMs-introduction.html

# %%
# !jupyter nbconvert your_notebook.ipynb --to html

# %%
# !jupyter nbconvert --to html --embed-images --template classic lecture-01-exercise-NLP-LLMs-introduction.ipynb
# Out:
# [NbConvertApp] Converting notebook lecture-01-exercise-NLP-LLMs-introduction.ipynb to html
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/llm-26-cpu/bin/jupyter-nbconvert", line 7, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/opt/anaconda3/envs/llm-26-cpu/lib/python3.12/site-packages/jupyter_core/application.py", line 284, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/anaconda3/envs/llm-26-cpu/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/anaconda3/envs/llm-26-cpu/lib/python3.12/site-packages/nbconvert/nbconvertapp.py", line 423, in start
#     self.convert_notebooks()
#   File "/opt/anaconda3/envs/llm-26-cpu/lib/python3.12/site-packages/nbconvert/nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
# ...
